# %%
# !pip install -q torch torchvision

import os
from PIL import Image
from torchvision import transforms
import random

# %%
# Diretórios
input_dir = "/Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/cnn-kit-dataset"
output_dir = "/Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset"

# %%
# Transformações de Data Augmentation
augment = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomRotation(25),
    transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),
    transforms.RandomHorizontalFlip(p=0.5),
    transforms.RandomAffine(degrees=10, translate=(0.1, 0.1), scale=(0.9, 1.1)),
])

# %%
# Função para criar dataset aumentado
def augment_dataset(input_base, output_base, num_augmented=300):
    for liga in os.listdir(input_base):
        liga_path = os.path.join(input_base, liga)
        if not os.path.isdir(liga_path):
            continue

        for clube in os.listdir(liga_path):
            clube_path = os.path.join(liga_path, clube)
            if not os.path.isdir(clube_path):
                continue

            # Criar diretório de output
            out_clube_dir = os.path.join(output_base, liga, clube)
            os.makedirs(out_clube_dir, exist_ok=True)

            # Processar cada imagem da pasta do clube
            for image_name in os.listdir(clube_path):
                image_path = os.path.join(clube_path, image_name)
                try:
                    image = Image.open(image_path).convert("RGB").resize((224, 224))
                except:
                    print(f"Erro ao abrir imagem: {image_path}")
                    continue

                # Criar múltiplas versões augmentadas
                for i in range(num_augmented):
                    aug_image = augment(image)
                    aug_name = f"{clube}_{i:03}.png"
                    aug_path = os.path.join(out_clube_dir, aug_name)
                    aug_image.save(aug_path)

                print(f"{clube}: {num_augmented} imagens guardadas em {out_clube_dir}")

print("A começar o processo de data augmentation...")
augment_dataset(input_dir, output_dir)
print("Augmentation concluído com sucesso!")
# Out:
# A começar o processo de data augmentation...
# ogc-nice: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/ogc-nice
# clermont-foot-63: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/clermont-foot-63
# rc-strasbourg-alsace: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/rc-strasbourg-alsace
# estac-troyes: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/estac-troyes
# losc-lille: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/losc-lille
# montpellier-herault: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/montpellier-herault
# stade-rennais-fc: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/stade-rennais-fc
# as-monaco: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/as-monaco
# rc-lens: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/rc-lens
# fc-lorient: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/fc-lorient
# fc-metz: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/fc-metz
# paris-saint-germain: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/paris-saint-germain
# olympique-lyonnais: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/olympique-lyonnais
# stade-de-reims: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/french-ligue1/stade-de-reims
# atalanta: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/atalanta
# salernitana: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/salernitana
# torino: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/torino
# bologna: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/bologna
# lazio: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/lazio
# roma: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/roma
# sassuolo: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/sassuolo
# ac-milan: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/ac-milan
# cagliari: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/cagliari
# udinese: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/udinese
# inter: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/inter
# fiorentina: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/fiorentina
# napoli: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/serie-a/napoli
# chelsea: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/chelsea
# arsenal: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/arsenal
# manchester-city: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/manchester-city
# watford: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/watford
# west-ham-united: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/west-ham-united
# leicester-city: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/leicester-city
# newcastle-united: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/newcastle-united
# leeds-united: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/leeds-united
# crystal-palace: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/crystal-palace
# crystal-palace: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/crystal-palace
# brentford: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/brentford
# everton: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/everton
# liverpool: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/liverpool
# burnley: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/burnley
# wolves: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/premier-league/wolves
# moenchengladbach: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/moenchengladbach
# schalke: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/schalke
# furth: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/furth
# hertha-bsc-berlin: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/hertha-bsc-berlin
# nuremberg: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/nuremberg
# dusseldorf: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/dusseldorf
# hamburg: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/hamburg
# hannover: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/hannover
# leverkusen: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/leverkusen
# frankfurt: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/frankfurt
# mainz: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/mainz
# dortmund: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/dortmund
# stuttgart: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/stuttgart
# bayern: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/bayern
# augsburg: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/augsburg
# bremen: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/bremen
# bremen: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/bundesliga/bremen
# cadiz: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/cadiz
# valencia: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/valencia
# celta: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/celta
# mallorca: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/mallorca
# real-madrid: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/real-madrid
# levante: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/levante
# rayo-vallecano: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/rayo-vallecano
# villarreal: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/villarreal
# osasuna: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/osasuna
# real-betis: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/real-betis
# getafe: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/la-liga/getafe
# vitoria-sc: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/vitoria-sc
# cd-tondela: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/cd-tondela
# gd-estoril-praia: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/gd-estoril-praia
# fc-porto: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/fc-porto
# fc-alverca: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/fc-alverca
# benfica: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/benfica
# sporting-cp: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/sporting-cp
# moreirense-fc: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/moreirense-fc
# sc-braga: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/sc-braga
# cf-estrela-amadora: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/cf-estrela-amadora
# santa-clara: 300 imagens guardadas em /Users/pedrofs/Library/CloudStorage/OneDrive-ISCTE-IUL/Mestrado/2ªSem/APVC/Projeto/dataset/augmented-cnn-kit-dataset/liga-betclic/santa-clara
# Augmentation concluído com sucesso!
